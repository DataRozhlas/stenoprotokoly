# %%
import polars as pl
import altair as alt

# %%
pl.Config.set_tbl_rows(150)
pl.Config.set_fmt_str_lengths(150)
pl.Config.set_tbl_width_chars(200)
# Out:
# polars.config.Config

# %%
df = pl.read_parquet(
    "data/projevy.parquet"
).filter(
    pl.col('datum').dt.year() >= 1918
).drop_nulls(
    subset=['datum']
)

# %%
def hledej(retezec, doslova=False, frejm=df):
    return frejm.filter(
    pl.col('text').str.contains(retezec, literal=doslova)
).group_by_dynamic(
    index_column='datum',every='1y').agg(pl.col('text').unique().len()
).join(
    frejm.group_by_dynamic(index_column='datum',every='1y').agg(pl.col('text').unique().len()), 
    on='datum', how='left'
).with_columns(
    (pl.col('text') / pl.col('text_right')).alias('podil')
).with_columns(
        pl.lit(retezec).alias('co')
)

# %%
alt.Chart(
    hledej("Brno").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej("[Gg]ottwaldov").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej("[Zz]lín").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej("Bečv").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej("Šlunkn").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej("[Bb]ratislav").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej("[Ww]ashingto").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej("[Bb]erlín").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej("[Mm]osk[ev]").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej("[Oo]strav[aysěuo]").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej("[Žž]idenic").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
hledej(r"[Ll]iberec")
# Out:
# shape: (92, 5)
# ┌────────────┬──────┬────────────┬──────────┬────────────┐
# │ datum      ┆ text ┆ text_right ┆ podil    ┆ co         │
# │ ---        ┆ ---  ┆ ---        ┆ ---      ┆ ---        │
# │ date       ┆ u32  ┆ u32        ┆ f64      ┆ str        │
# ╞════════════╪══════╪════════════╪══════════╪════════════╡
# │ 1919-01-01 ┆ 7    ┆ 3480       ┆ 0.002011 ┆ [Ll]iberec │
# │ 1920-01-01 ┆ 36   ┆ 4810       ┆ 0.007484 ┆ [Ll]iberec │
# │ 1921-01-01 ┆ 42   ┆ 6618       ┆ 0.006346 ┆ [Ll]iberec │
# │ 1922-01-01 ┆ 39   ┆ 6295       ┆ 0.006195 ┆ [Ll]iberec │
# │ 1923-01-01 ┆ 24   ┆ 4555       ┆ 0.005269 ┆ [Ll]iberec │
# │ 1924-01-01 ┆ 26   ┆ 5045       ┆ 0.005154 ┆ [Ll]iberec │
# │ 1925-01-01 ┆ 23   ┆ 3927       ┆ 0.005857 ┆ [Ll]iberec │
# │ 1926-01-01 ┆ 31   ┆ 5898       ┆ 0.005256 ┆ [Ll]iberec │
# │ 1927-01-01 ┆ 32   ┆ 5376       ┆ 0.005952 ┆ [Ll]iberec │
# │ 1928-01-01 ┆ 30   ┆ 5048       ┆ 0.005943 ┆ [Ll]iberec │
# │ 1929-01-01 ┆ 15   ┆ 3196       ┆ 0.004693 ┆ [Ll]iberec │
# ...

# %%
alt.Chart(
    hledej(r"[Ll]iberec").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej(r" [Vv]íd[en]").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    hledej(r"nebylo").to_pandas(),
    width = 600
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('podil:Q')
)
# Out:
# C:\Users\micha\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.Chart(
    df.group_by_dynamic(index_column='datum',every='1y').agg(pl.col('text').unique().len()).tail(40).to_pandas()
).mark_bar(
).encode(
    alt.X('datum:T'),
    alt.Y('text:Q')
)
# Out:
# alt.Chart(...)
